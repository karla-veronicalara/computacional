# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def integra_h2(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(1,len(x)-1):
        integral += f[i+1] + 22*f[i] + f[i-1]
    integral += 0.5*(17*f[0] + 7*f[1] + f[2] - f[3])
    integral += 0.5*(17*f[-1] + 7*f[-2] + f[-3] - f[-4])
    return integral*h/24

def int_Riem(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(len(x)-1):
        integral += f[i]
    return integral*h

def integra_h2_impar(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(1,len(x),2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

def integra_h2_par(f,x):
    integral , h = 0 , x[1]-x[0]
    for i in range(2,len(x),2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    integral += (23*f[0] + 26*f[1] - 4*f[2] + 6*f[3] - 3*f[4])/16
    return integral*h/3

def integra_h2_mejorado(f,x):
    if len(x)%2 == 0:
        integral = integra_h2_par(f,x)
    else:
        integral = integra_h2_impar(f,x)
    return integral

def integra_h2_unificado(f,x):
    integral , h , N = 0 , x[1]-x[0] , len(x)
    if N%2 == 0:
        inicio = 2
        integral += (23*f[0] + 26*f[1] - 4*f[2] + 6*f[3] - 3*f[4])/16
    else:
        inicio = 1
    for i in range(inicio,N,2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

# %%
x = np.linspace(0,np.pi,51)
y = np.sin(x)
print('h = ', x[1]-x[0])
print('Integral h2 ',integra_h2(y,x))
print('Integral Riem ',int_Riem(y,x))
print('Integral h2 mejorado',integra_h2_mejorado(y,x))
# Out:
# h =  0.06283185307179587
# Integral h2  2.0000014675586244
# Integral Riem  1.9993419830762615
# Integral h2 mejorado 2.0000001732531385

# %%
#eEmpezamos a medir rendimientos
# %timeit integra_h2(y,x)
# Out:
# 12.6 μs ± 307 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
x = np.linspace(0,np.pi,51)
y = np.sin(x)
print('h = ', x[1]-x[0])
print('Integral h2 ',integra_h2(y,x))
print('Integral Riem ',int_Riem(y,x))

# %%
from numba import njit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from numba import njit
#
# ModuleNotFoundError: No module named 'numba'

# %%
def integra_h2_unificado_numba(f,x):
    integral , h , N = 0 , x[1]-x[0] , len(x)
    if N%2 == 0:
        inicio = 2
        integral += (23*f[0] + 26*f[1] - 4*f[2] + 6*f[3] - 3*f[4])/16
    else:
        inicio = 1
    for i in range(inicio,N,2):
        integral += f[i+1] + 4*f[i] + f[i-1]
    return integral*h/3

# %%
x = np.linspace(0,np.pi,51)
y = np.sin(x)
print('h = ', x[1]-x[0])
print('Integral h2 unificado',integra_h2(y,x))
