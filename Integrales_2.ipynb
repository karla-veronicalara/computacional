# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Vamos a sacar la primitiva de una funciòn 
#neceesitaremos cosas de la clase pasada. las funciones h1 y h2 no nos sirve pq va de dos en dos o asì 
def primitiva(f,x):
    integral, h = np.zeros_like(f) , x[1]-x[0]
    integral[0]= 0.5*(17*f[0] + 7*f[1] + f[2] - f[3])

    for i in range(1,len(x)-1):
        integral[i] += integral[i-1] + (f[i] + 22*f[i] + f[i-1])

    integral[-1] =0.5*(17*f[-1] + 7*f[-2] + f[-3] - f[-4])
    return integral*h/24

    #Hicimos cambios q no supe xd

# %%
x = np.linspace(0,10)
y = np.sin(x)

int_y = primitiva(y,x)

plt.plot(x,y)
plt.plot(x,int_y)
plt.grid()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def primitiva_v1(f,x):
    integral , h = np.zeros_like(f), x[1]-x[0]
    integral[0] = 0

    for i in range(1,len(x)-4):
        integral[i] += integral

# %%
#Fi; drivsdsd r integrales
