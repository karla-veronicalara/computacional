# %%
import numpy as np
import matplotlib.plyplot as plt

# %%
def raiz_bisec(f,xi,xd,error = 1e-8):
    fi ,fd = f(xi) , f(xd)
    if fi*fd < 0:
        x_med = 0.5*(xi+xd)
        f_med = f(x_med)

        while abs(f_med)>error and:
            if fi*f_med < 0: #pivoteo
                xd = x_med
                else
